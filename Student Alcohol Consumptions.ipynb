# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Ac =pd.read_csv("C:/Users/nishanth kumar/Desktop/student-mat.csv")

# %%
Ac
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
sns.set_style('darkgrid')

# %%
sns.boxplot(x='sex',y='health',data=Ac)
plt.show()

# %%
Ac.keys()
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
plt.title('studytime')
plt.plot(Ac['studytime'])

plt.subplot(2,2,2)
plt.title('traveltime')
plt.plot(Ac['traveltime'])

plt.subplot(2,2,3)
plt.title('freetime')
plt.plot(Ac['activities'])

plt.subplot(2,2,4)
plt.title('health')
plt.plot(Ac['health'])
plt.show()

# %%
sns.jointplot(x='guardian',y='absences',color='g',data = Ac)
plt.show()

# %%
sns.boxplot(x='age',y='health',data=Ac)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
sns.boxplot(x='sex',y='traveltime',data = Ac)

plt.subplot(1,2,2)
sns.boxplot(x='sex',y='studytime',data = Ac)
plt.show()

# %%
sns.boxplot(x='Mjob',y='studytime',data = Ac)
plt.show()

# %%
sns.boxplot(x='Fjob',y='studytime',data=Ac)
plt.show()

# %%
sns.barplot(x='traveltime',y='absences',data=Ac)
plt.ylim(1,10)
plt.show()

# %%
sns.boxplot(x='internet',y='health',hue='activities',data=Ac)
plt.show()

# %%
sns.distplot(Ac['age'])
plt.show()
